# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/shruti/Desktop/Integrated/Franchise 500.csv", index_col=0,
                low_memory=False)
symbols = '!@#$%^&*()_=[]-'
letters = 'abcdefghijklomnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'
numbers = '0123456789'
df
# Out:
#                            FS500 Rank                              Industry  \
# Franchise name
# Taco Bell                           1                                  Food
# Dunkin'                             2                                Coffee
# The UPS Store                       3             Postal & Business Centers
# Popeyes Louisiana Kitchen           4                               Chicken
# Culver's                            5                        Frozen Custard
# ...                               ...                                   ...
# Junk King                         496          Moving/Junk-Removal Services
# Caring Transitions                497                Miscellaneous Services
# CarePatrol                        498                           Senior Care
# Little Medical School             499  Children's Enrichment Programs: STEM
# Maaco                             500        Automotive Appearance Services
#
# ...

# %%
df.shape
# Out:
# (500, 33)

# %%
df.head()
# Out:
#                            FS500 Rank                   Industry  \
# Franchise name
# Taco Bell                           1                       Food
# Dunkin'                             2                     Coffee
# The UPS Store                       3  Postal & Business Centers
# Popeyes Louisiana Kitchen           4                    Chicken
# Culver's                            5             Frozen Custard
#
#                                                                     Category  \
# Franchise name
# Taco Bell                                                       Mexican Food
# Dunkin'                                       Coffee, doughnuts, baked goods
# The UPS Store              Postal, business, printing, and communications...
# Popeyes Louisiana Kitchen                   Fried chicken, seafood, biscuits
# Culver's                                   Frozen custard, specialty burgers
#
#                            Category Rank                   Parent Company  \
# ...

# %%
df = df.replace("NA", np.nan)

# %%
#count missing values for each variable
nullcolumn = df.isnull().sum()

# %%
nullcolumns = pd.DataFrame(nullcolumn)
nullcolumns.sort_values(by=[0], inplace=True, ascending=False)
nullcolumns
# Out:
#                                  0
# Franchise Fee High             375
# Parent Company                 160
# Ad Fee                         133
# Royalty                         67
# Franchise Fee Low                8
# Term of Agreement                4
# # of employees at HQ             3
# Headquarters State               1
# Renewable?                       0
# Franchising since                0
# FS500 Rank                       0
# Founded                          0
# Classroom Training               0
# Renewable                        0
# Growth_Rate                      0
# US_Rate                          0
# Intl_Rate                        0
# On the Job Training              0
# FS Units 2020                    0
# Industry                         0
# Intl Units 2020                  0
# Company Owned 2020               0
# Total Units 2020                 0
# FS Units 2021                    0
# Intl Units 2021                  0
# Company Owned 2021               0
# ...

# %%
df.describe()
# Out:
#        FS500 Rank  Low Initial investment (000s)  High Initiatl Inv (000s)  \
# count  500.000000                   5.000000e+02              5.000000e+02
# mean   250.500000                   6.901200e+05              2.420536e+06
# std    144.481833                   3.072131e+06              1.162053e+07
# min      1.000000                   2.000000e+03              1.400000e+04
# 25%    125.750000                   7.700000e+04              1.580000e+05
# 50%    250.500000                   1.500000e+05              3.455000e+05
# 75%    375.250000                   3.092500e+05              7.852500e+05
# max    500.000000                   4.490000e+07              1.290000e+08
#
#        Total Units 2021  Company Owned 2021  Intl Units 2021  FS Units 2021  \
# count        500.000000          500.000000       500.000000     500.000000
# mean        1052.828000           84.128000       436.518000     532.182000
# ...

# %%
df['Headquarters State'].value_counts().head(10).plot(kind='bar', color='navy')
plt.title('Bar Chart of Top 10 Headquarters State')
# Out:
# Text(0.5, 1.0, 'Bar Chart of Top 10 Headquarters State')

# %%
AveGrowthS = df.groupby('Headquarters State', as_index=False)['Growth_Rate'].mean()
plt.figure(figsize=(15,10))
plt.bar(AveGrowthS['Headquarters State'], AveGrowthS['Growth_Rate'])
plt.xlabel("Headquarters State")
plt.ylabel("Average Growth Rate")
plt.title("")
# Out:
# Text(0.5, 1.0, '')

# %%
df.drop(['Renewable?','Intl_Rate','CompanyOwned_Rate','Headquarters City','Headquarters State','Franchise Fee High','Category','Parent Company','Category Rank'],inplace =True, axis =1)

# %%
df['Growth_Rate'] = (df['Total Units 2021']-df['Total Units 2020']) / df['Total Units 2020']*100

# %%
df['Growth_Rate']
# Out:
# Franchise name
# Taco Bell                     0.888650
# Dunkin'                      -2.476190
# The UPS Store                 1.727411
# Popeyes Louisiana Kitchen     5.863192
# Culver's                      5.620915
#                                ...
# Junk King                    17.857143
# Caring Transitions           13.207547
# CarePatrol                   12.408759
# Little Medical School         0.000000
# Maaco                        -6.593407
# Name: Growth_Rate, Length: 500, dtype: float64

# %%
pd.options.display.max_rows = 136
df['Industry'].value_counts()
# Out:
# Hotels & Motels                                  27
# Senior Care                                      18
# Fitness                                          18
# Commercial Cleaning                              12
# Restoration Services                             12
# Chicken                                          10
# Children's Fitness Programs                      10
# Childcare                                        10
# Real Estate                                      10
# Staffing/Recruiting                               9
# Hair Care                                         9
# Pizza                                             9
# Children's Enrichment Programs: STEM              8
# Massage & Spa Services                            8
# Hamburgers                                        8
# Tutoring                                          7
# Residential Cleaning                              7
# Miscellaneous Retail Businesses                   7
# ...

# %%
df['Industry'] = df['Industry'].str.replace("'","")

# %%
df['Industry'] = df['Industry'].replace(['Chicken','Pizza','Hamburgers','Ice Cream','Mexican Food','Asian Food','Miscellaneous Food/Beverage Businesses','Coffee','Submarine Sandwiches','Seafood','Frozen Custard','Miscellaneous Baked Goods','Hot Dogs','Breakfast/Brunch Restaurants','Philly Cheesesteak Sandwiches','Teas','Miscellaneous Quick-Service Restaurants','Miscellaneous Frozen Desserts','Candy','Mediterranean Food','Food','Miscellaneous Sandwiches','Miscellaneous Full-Service Restaurants','Acai Bowls','Cinnamon Rolls','Smoothies/Juices'],'Food_Chain')
df['Industry'] = df['Industry'].replace(['Senior Care','Childcare','Eye Care','Hearing Aids','Miscellaneous Health Services','Miscellaneous Health Products'],'Healthcare')
df['Industry'] = df['Industry'].replace(['Fitness','Childrens Fitness Programs','Miscellaneous Personal-Care Businesses','Hair Care','Massage & Spa Services','Waxing','Salon Suites','Lash & Brow Services','Chiropractic Services','Tanning','Physical Therapy','Plumbing'],'Personal_Care')
df['Industry'] = df['Industry'].replace(['Lawn & Tree Care','Wood Refinishing','Miscellaneous Maintenance Businesses','Grout Maintenance','Pool Maintenance','Home Inspections','Miscellaneous Home-Improvement Businesses','Kitchen & Bath Remodeling','Concrete Coatings','Home Building','Window Coverings','Painting'],'Home_Improvement')
df['Industry'] = df['Industry'].replace(['Dog Training','Pet Stores','Pet Care','Miscellaneous Pet Businesses'],'Pets_Service')
df['Industry'] = df['Industry'].replace(['Miscellaneous Retail Businesses','Childrens Retail','Convenience Stores','Tools Distribution','Apparel & Accessories','Sports Equipment & Apparel'],'Retail')
df['Industry'] = df['Industry'].replace(['Swimming Lessons','Business Training Programs','Tutoring','Childrens Enrichment Programs: Miscellaneous','Childrens Enrichment Programs: Art','Childrens Enrichment Programs: Music','Childrens Enrichment Programs: STEM'],'Education')
df['Industry'] = df['Industry'].replace(['Weight-Loss Services','Miscellaneous Financial Services','Property Management','Business Financial Services','Tax Services','Insurance','Real Estate'],'Financial_Service')
df['Industry'] = df['Industry'].replace(['Miscellaneous Business Services','Business Brokerages','Advertising Services','Staffing/Recruiting','Printing/Marketing Services'],'Business_Service')
df['Industry'] = df['Industry'].replace(['Drywall Repair','Garage-Door Repair/Installation','Glass Repair','Restoration Services','Home Repairs/Handyman Services','Electronics Repairs/Sales','Leather & Vinyl Repair','Locksmith Services'],'Repairing_Service')
df['Industry'] = df['Industry'].replace(['Car-Wash Services','Automotive Appearance Services','Miscellaneous Automotive Products & Services','Automotive Repair & Maintenance Services','Wheels & Tires','Windshield Repair','Oil-Change Services'],'Auto_Service')
df['Industry'] = df['Industry'].replace(['Adventure Parks/Entertainment Centers','Boat Clubs','Escape Rooms','Sports Bars/Pubs','Miscellaneous Recreation Businesses','DIY/Paint-&-Sip Studios','Campgrounds'],'Recreation')
df['Industry'] = df['Industry'].replace(['Hotels & Motels'],'Hotel')
df['Industry'] = df['Industry'].replace(['Security Services','Networking Groups','IT Services','Request Info'],'Tech_Service')
df['Industry'] = df['Industry'].replace(['Window Cleaning','Carpet & Upholstery Services','Moving/Junk-Removal Services','Residential Cleaning','Commercial Cleaning','HVAC/Duct-Cleaning Services','Crime-Scene Cleaning','Dry Cleaning & Laundry Services'],'Cleaning_Service')
df['Industry'] = df['Industry'].replace(['Laboratory Services','Insulation','Lighting Services','Electrical Services','Asphalt Maintenance','Photography & Video Services','Miscellaneous Services','Postal & Business Centers','Ices','Flooring','Coworking Spaces','Embroidery & Screen Printing','Pest Control','Signs','Organization/Storage Systems','Travel Agencies'],'Other')

# %%
df['Industry'].value_counts()
# Out:
# Hotels & Motels                                 27
# Fitness                                         18
# Senior Care                                     18
# Commercial Cleaning                             12
# Restoration Services                            12
# Real Estate                                     10
# Chicken                                         10
# Childcare                                       10
# Childrens Fitness Programs                      10
# Pizza                                            9
# Hair Care                                        9
# Staffing/Recruiting                              9
# Childrens Enrichment Programs: STEM              8
# Massage & Spa Services                           8
# Hamburgers                                       8
# Tutoring                                         7
# Ice Cream                                        7
# Miscellaneous Retail Businesses                  7
# ...

# %%
df['Industry'].value_counts().head(10).plot(kind='pie', cmap='coolwarm')
plt.title('Pie Chart of Top 10 Industry')
# Out:
# Text(0.5, 1.0, 'Pie Chart of Top 10 Industry')

# %%
AveGrowth = df.groupby('Industry', as_index=False)['Growth_Rate'].mean()
AveGrowths = pd.DataFrame(AveGrowth)
AveGrowths.sort_values(by=['Growth_Rate'], inplace=True, ascending=False)
AveGrowths.head(16)
# Out:
#                                       Industry  Growth_Rate
# 15                           Car-Wash Services    67.441860
# 82   Miscellaneous Home-Improvement Businesses    56.323529
# 36                              Drywall Repair    45.652174
# 68                           Lighting Services    31.645570
# 78               Miscellaneous Frozen Desserts    31.578947
# 0                                   Acai Bowls    30.735931
# 92                           Networking Groups    29.508197
# 76            Miscellaneous Financial Services    29.230769
# 62                                   Insurance    27.678689
# 25                       Chiropractic Services    26.937536
# 86     Miscellaneous Quick-Service Restaurants    26.315789
# 87         Miscellaneous Recreation Businesses    24.668330
# 11                 Business Financial Services    24.411713
# 104                           Pool Maintenance    23.308415
# 29                           Concrete Coatings    22.580645
# ...

# %%
plt.figure(figsize=(10,8))
plt.xticks(rotation='vertical')
plt.bar(AveGrowths['Industry'], AveGrowths['Growth_Rate'])
plt.xlabel("Industry")
plt.ylabel("Average Growth Rate")
#plt.title("")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth1 = df.groupby('Ad Fee', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth1['Ad Fee'], AveGrowth1['Growth_Rate'])
plt.xlabel("Ad Fee")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Taco Bell to Maaco
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FS500 Rank                     500 non-null    int64
#  1   Industry                       500 non-null    object
#  2   Low Initial investment (000s)  500 non-null    int64
#  3   High Initiatl Inv (000s)       500 non-null    int64
#  4   Total Units 2021               500 non-null    int64
#  5   Company Owned 2021             500 non-null    int64
#  6   Intl Units 2021                500 non-null    int64
#  7   FS Units 2021                  500 non-null    int64
#  8   Total Units 2020               500 non-null    int64
#  9   Company Owned 2020             500 non-null    int64
#  10  Intl Units 2020                500 non-null    int64
#  11  FS Units 2020                  500 non-null    int64
# ...

# %%
AveGrowth1 = df.groupby('Total Units 2020', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth1['Total Units 2020'], AveGrowth1['Growth_Rate'])
plt.xlabel("Total Units 2020")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth1 = df.groupby('Total Units 2021', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth1['Total Units 2021'], AveGrowth1['Growth_Rate'])
plt.xlabel("Total Units 2021")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth1 = df.groupby('High Initiatl Inv (000s)', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth1['High Initiatl Inv (000s)'], AveGrowth1['Growth_Rate'])
plt.xlabel("High Initiatl Inv (000s)")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth2 = df.groupby('Royalty', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth2['Royalty'], AveGrowth2['Growth_Rate'])
plt.xlabel("Royalty")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth3 = df.groupby('Classroom Training', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth3['Classroom Training'], AveGrowth3['Growth_Rate'])
plt.xlabel("Classroom Training Hours")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth4 = df.groupby('On the Job Training', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth4['On the Job Training'], AveGrowth4['Growth_Rate'])
plt.xlabel("On the Job Training Hours")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth5 = df.groupby('Founded', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth5['Founded'], AveGrowth5['Growth_Rate'])
plt.xlabel("Founded")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
AveGrowth6 = df.groupby('Franchising since', as_index=False)['Growth_Rate'].mean()
plt.plot(AveGrowth6['Franchising since'], AveGrowth6['Growth_Rate'])
plt.xlabel("Franchising since")
plt.ylabel("Average Growth Rate")
# Out:
# Text(0, 0.5, 'Average Growth Rate')

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# a simple line plot
df.plot(kind='bar',x='# of employees at HQ',y='Growth_Rate')
# Out:
# <AxesSubplot:xlabel='# of employees at HQ'>

# %%
import matplotlib.pyplot as plt
import pandas as pd

# gca stands for 'get current axis'
ax = plt.gca()

df.plot(kind='line',x='# of employees at HQ',y='Growth_Rate',ax=ax)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Taco Bell to Maaco
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   FS500 Rank                     500 non-null    int64
#  1   Industry                       500 non-null    object
#  2   Low Initial investment (000s)  500 non-null    int64
#  3   High Initiatl Inv (000s)       500 non-null    int64
#  4   Total Units 2021               500 non-null    int64
#  5   Company Owned 2021             500 non-null    int64
#  6   Intl Units 2021                500 non-null    int64
#  7   FS Units 2021                  500 non-null    int64
#  8   Total Units 2020               500 non-null    int64
#  9   Company Owned 2020             500 non-null    int64
#  10  Intl Units 2020                500 non-null    int64
#  11  FS Units 2020                  500 non-null    int64
# ...

# %%
df['Industry'] = df['Industry'].replace(['Other'],'AAA')
Industry_cat = pd.get_dummies(df['Industry'],drop_first=True)
Industry_cat
# Out:
#                            Adventure Parks/Entertainment Centers  \
# Franchise name
# Taco Bell                                                      0
# Dunkin'                                                        0
# The UPS Store                                                  0
# Popeyes Louisiana Kitchen                                      0
# Culver's                                                       0
# ...                                                          ...
# Junk King                                                      0
# Caring Transitions                                             0
# CarePatrol                                                     0
# Little Medical School                                          0
# Maaco                                                          0
#
#                            Advertising Services  Apparel & Accessories  \
# Franchise name
# Taco Bell                                     0                      0
# ...

# %%
df = pd.concat([df,Industry_cat],axis =1)
df.drop(['Industry'],inplace =True,axis = 1)

# %%
sns.lmplot(x='FS Units 2020',y='FS Units 2021',data=df)

# %%
sns.lmplot(x='Intl Units 2020',y='Intl Units 2021',data=df)

# %%
sns.lmplot(x='Total Units 2020',y='Total Units 2021',data=df)

# %%
sns.lmplot(x='Company Owned 2020',y='Company Owned 2021',data=df)

# %%
df.drop(['Total Units 2020','FS Units 2020','Intl Units 2020','Company Owned 2020'], inplace = True, axis = 1)

# %%
plt.figure(figsize=(10,5))
df.corr()['FS500 Rank'].sort_values().drop('FS500 Rank').plot(kind='bar', color='maroon')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
df.corr()['Growth_Rate'].sort_values().drop('Growth_Rate').plot(kind='bar', color='maroon')
# Out:
# <AxesSubplot:>

# %%
df3 = df

# %%
sns.boxplot(df['Ad Fee'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ad Fee'>

# %%
df['Ad Fee'] = df['Ad Fee'].fillna(df['Ad Fee'].median())

# %%
sns.boxplot(df['Royalty'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Royalty'>

# %%
df['Royalty'] = df['Royalty'].fillna(df['Royalty'].median())

# %%
sns.boxplot(df['Franchise Fee Low'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Franchise Fee Low'>

# %%
df['Franchise Fee Low'] = df['Franchise Fee Low'].fillna(df['Franchise Fee Low'].median())

# %%
df['Term of Agreement'] = df['Term of Agreement'].fillna(0)

# %%
sns.boxplot(df['# of employees at HQ'])
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='# of employees at HQ'>

# %%
df['# of employees at HQ'] = df['# of employees at HQ'].fillna(df['# of employees at HQ'].median())

# %%
nullcolumn = df.isnull().sum()
nullcolumns = pd.DataFrame(nullcolumn)
nullcolumns.sort_values(by=[0], inplace=True, ascending=False)
nullcolumns
# Out:
#                                          0
# FS500 Rank                               0
# Miscellaneous Quick-Service Restaurants  0
# Miscellaneous Full-Service Restaurants   0
# Miscellaneous Health Products            0
# Miscellaneous Health Services            0
# ...                                     ..
# Coworking Spaces                         0
# Crime-Scene Cleaning                     0
# DIY/Paint-&-Sip Studios                  0
# Dog Training                             0
# Wood Refinishing                         0
#
# [158 rows x 1 columns]

# %% [markdown]
# # Ranking Model

# %%
df_rank = df
#df_rank.drop(['Growth_Rate'], inplace = True, axis = 1)
df_rank.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Taco Bell to Maaco
# Columns: 158 entries, FS500 Rank to Wood Refinishing
# dtypes: float64(9), int64(14), uint8(135)
# memory usage: 175.8+ KB

# %%
from sklearn.model_selection import train_test_split
X = df_rank.iloc[:, 1:33].values
y = df_rank.iloc[:, 0].values
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf.fit(train_X, train_y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predictions = rf.predict(test_X)
errors = abs(predictions - test_y)

print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 99.94 degrees.

# %%
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)

print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 41.67 %.

# %%
from sklearn import linear_model

regr = linear_model.LinearRegression()
regr.fit (train_X, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [-3.25203526e-06 -6.52119034e-07 -1.26435272e-01  2.02290865e-03
#   2.49098527e-01 -3.77556708e-01  1.13479159e-01  1.23197058e-02
#  -2.35161214e-01  3.36320667e-01  8.06582261e-03  3.28051233e-01
#  -8.65524714e-02 -4.34505469e-04  6.24078639e+00 -8.51341417e+00
#   3.58669249e-01 -2.19564856e-01 -3.00296720e-01  1.33352471e+00
#   1.91289362e-01  4.60729897e+01 -1.31032460e+02  4.08329119e+01
#   2.84217094e-14  5.38352947e+01  5.84336205e+01  1.97072374e+02
#   7.04955763e+01 -9.31567107e+01  2.00421400e+02 -9.93141410e+01]

# %%
y_hat= regr.predict(test_X)

print("Residual sum of squares: %.2f"
      % np.mean((y_hat - test_y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(test_X, test_y))
# Out:
# Residual sum of squares: 18030.33
# Variance score: 0.08

# %% [markdown]
# # Growth Rate Model

# %%
df3 = pd.DataFrame(data=df_rank)
df3.drop(['Growth_Rate'], inplace = True, axis = 1)
X = df3.iloc[:, 1:32].values
y = df_rank.iloc[:, 17].values
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
rf = RandomForestRegressor(n_estimators = 100, random_state = 0)
rf.fit(train_X, train_y)
# Out:
# RandomForestRegressor(random_state=0)

# %%
predictions = rf.predict(test_X)
errors = abs(predictions - test_y)

print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.04 degrees.

# %%
mape = 100 * (errors / test_y)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)

print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 99.73 %.

# %%
regr = linear_model.LinearRegression()
regr.fit (train_X, train_y)
# The coefficients
print ('Coefficients: ', regr.coef_)
# Out:
# Coefficients:  [ 3.18800303e-20 -1.50877744e-21  2.15604924e-13 -2.15833240e-13
#  -2.16171792e-13 -2.14779142e-13 -7.78352796e-14  7.79469631e-14
#   7.84681082e-14  7.69724827e-14  8.47098422e-18  3.63481444e-16
#  -2.08844722e-16  1.53294128e-18  5.62348855e-16 -1.29958765e-15
#   1.00000000e+00  2.09537891e-16 -5.51024315e-15 -6.60265857e-15
#   1.53702572e-15 -4.79399321e-16  1.73963730e-15  2.16840434e-19
#  -1.09260268e-15 -6.38482285e-16 -4.01121379e-16  5.47295320e-16
#   2.80860080e-15 -2.34944691e-15 -3.80182609e-15]

# %%
y_hat= regr.predict(test_X)

print("Residual sum of squares: %.2f"
      % np.mean((y_hat - test_y) ** 2))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(test_X, test_y))
# Out:
# Residual sum of squares: 0.00
# Variance score: 1.00
